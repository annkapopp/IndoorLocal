# %%
import numpy as np
import pandas as pd
import utils

# %%
#öoad calibration data and store as np array
filename_cal = "data/gebaeude64_cali/Accelerometer.csv"

cal_gyro = pd.read_csv(filename_cal)

cal_gyro = np.asarray(cal_gyro)

# %%
utils.plot_acc(cal_gyro, "norm")
